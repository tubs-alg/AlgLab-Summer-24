# %% [markdown]
# # Steiner Tree Problem in Unweighted Graphs

# %%
import networkx as nx
import random
from solver import SteinerTreeSolver, Instance

# %%
G = nx.connected_watts_strogatz_graph(20, 4, 0.2)
terminals = random.sample(list(G.nodes()), 5)

positions = nx.layout.kamada_kawai_layout(G)
nx.draw_networkx(
    G,
    pos=positions,
    node_color=["orange" if node in terminals else "grey" for node in G.nodes()],
)

# %%
solver = SteinerTreeSolver(Instance(G, terminals))
solution = solver.solve()
assert solution
# Out:
# Set parameter TimeLimit to value 900
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-8559U CPU @ 2.70GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5 rows, 40 columns and 20 nonzeros
# Model fingerprint: 0x63e33f41
# Variable types: 0 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 5 rows, 40 columns, 20 nonzeros
# Variable types: 0 continuous, 40 integer (40 binary)
#
# Root relaxation: objective 4.500000e+00, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.50000    0    3          -    4.50000      -     -    0s
# H    0     0                       8.0000000    4.50000  43.8%     -    0s
# H    0     0                       7.0000000    4.50000  35.7%     -    0s
#      0     0    5.00000    0    4    7.00000    5.00000  28.6%     -    0s
#      0     0    5.00000    0    6    7.00000    5.00000  28.6%     -    0s
#      0     0    5.00000    0    6    7.00000    5.00000  28.6%     -    0s
#      0     2    5.00000    0    6    7.00000    5.00000  28.6%     -    0s
# *   27     6               7       6.0000000    6.00000  0.00%   3.0    0s
#
# Cutting planes:
#   Gomory: 2
#   Lazy constraints: 30
#
# Explored 30 nodes (108 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 6 7 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
#
# User-callback calls 225, time in user-callback 0.03 sec

# %%
# Draw the solution
nx.draw_networkx_nodes(G, pos=positions, node_color="lightgrey")
nx.draw_networkx_edges(G, pos=positions, style="dashed", edge_color="lightgrey")
nx.draw_networkx(
    solution,
    pos=positions,
    node_color=["orange" if node in terminals else "grey" for node in solution.nodes()],
)
